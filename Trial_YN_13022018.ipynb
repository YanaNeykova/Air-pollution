# %%
import plotly.plotly as py
import plotly.graph_objs as go 

from datetime import datetime
import pandas as pd

# %%
df_pollution = pd.read_csv('https://dataset file for air pollution.csv')

df_locations = pd.read_csv('https://file for air pollution.csv')
df_locations.set_index('Sofia Location', inplace=True)

air_pollution_locations=list([
    dict(
        args=[ { 
            'mapbox.center.lat':40,
            'mapbox.center.lon':-92,
            'mapbox.zoom':3,
            'annotations[0].text':'Current status of the air pollution'
        } ],
        label='Sofia',
        method='relayout'
    )
])

for location, row in df_locations.iterrows():
    desc = []
    for col in df_locations.columns:
        if col not in ['Location/region','Latitude','Longitude']:
            if str(row[col]) not in ['None','nan','']: 
                desc.append( col + ': ' + str(row[col]).strip("'") )
    desc.insert(0, location)
    air_pollution_locaions.append( 
        dict(
            args=[ { 
                'mapbox.center.lat':row['Latitude'], 
                'mapbox.center.lon':float(str(row['Longitude']).strip("'")), 
                'mapbox.zoom':9,
                'annotations[0].text': '<br>'.join(desc)
            } ],
            label=' '.join(location.split(' ')[0:2]),
            method='relayout'
        )
    )

data = []location
for pollution_level in list(df_data.index):
    if pollution_level != 'unknown':
        trace = dict(
            lat = df_pollution [ df_pollution ['pollution_level'] == pollution_level ]['latitude'],
            lon = df_pollution [ df_pollution ['pollution_level'] == pollution_level ]['longitude'],
            name = pollution_level,
            marker = dict(size = 4),
            type = 'scattermapbox'
        )
    data.append(trace)

layout = dict(
    height = 700,
    margin = dict( t=0, b=0, l=0, r=0 ),
    font = dict( color='#FFFFFF', size=11 ),
    paper_bgcolor = '#000000',
    mapbox=dict(
        accesstoken='pk.eyJ1IjoieWFuYW5leWtvdmEiLCJhIjoiY2pzM2NuaXZhMjY5YzQzbjF4czI4bWlqaCJ9.EcynER0g8s_rRnf80pEZBA',
        bearing=0,
        center=dict(
            lat=38,
            lon=-94
        ),
        pitch=0,
        zoom=3,
        style='dark'
    ),
)

updatemenus=list([
    dict(
        buttons = neighbourhood [0:10],
        pad = {'r': 0, 't': 10},
        x = 0.1,
        xanchor = 'left',
        y = 1.0,
        yanchor = 'top',
        bgcolor = '#AAAAAA',
        active = 99,
        bordercolor = '#FFFFFF',
        font = dict(size=11, color='#000000')
    ),
    dict(
        buttons=list([
            dict(
                args=['mapbox.style', 'dark'],
                label='Dark',
                method='relayout'
            ),                    
            dict(
                args=['mapbox.style', 'light'],
                label='Light',
                method='relayout'
            ),
            dict(
                args=['mapbox.style', 'satellite'],
                label='Satellite',
                method='relayout'
            ),
            dict(
                args=['mapbox.style', 'satellite-streets'],
                label='Satellite with Streets',
                method='relayout'
            )                    
        ]),
        direction = 'up',
        x = 0.75,
        xanchor = 'left',
        y = 0.05,
        yanchor = 'bottom',
        bgcolor = '#000000',
        bordercolor = '#FFFFFF',
        font = dict(size=11)
    ),        
])

annotations = list([
    dict(text='Current status of the air pollution', font=dict(color='magenta',size=14), borderpad=10, 
         x=0.05, y=0.05, xref='paper', yref='paper', align='left', showarrow=False, bgcolor='black'),
    dict(text='Neighbourhoods', x=0.01, y=0.99, yref='paper', align='left', showarrow=False,font=dict(size=14))
])

layout['updatemenus'] = updatemenus
layout['annotations'] = annotations

figure = dict(data=data, layout=layout)
py.iplot(figure, filename='sofia_air_pollution_data')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Programmes\Anaconda3.5.2\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# D:\Programmes\Anaconda3.5.2\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# D:\Programmes\Anaconda3.5.2\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# ...
